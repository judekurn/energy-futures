# %% [markdown]
# # Pathways Diagrams
#
# This notebook contains codes for generating pathways diagrams used in the documents called "Pathways Documents" to be sent to expert participants.
#
# Updates history:
# * 17 July 2018 - Beautify codes using standard Python naming convention (e.g. CAPS for constant etc.)
# * 19 July 2018 - Added right side y tick marks label for D-01 to D-10
# * 20 July 2018 - Updated Adoption of EVs pathways based on review comment from Jean Andrey

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import Circle
# %matplotlib inline

# %%
# Data for extrapolating pathways for each descriptor is saved in the excel file
FILENAME = './data/pathways.xlsx'
# Standard figure size
FIG_SIZE = (12,8)

# %%
"""
Functions for this notebook
"""
def circle(x, y, radius=1.2):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)

def text(x, y, text, bgcolor):
    ax.text(x, y, text, backgroundcolor=bgcolor,
            ha='center', va='top', weight='bold', color='k')

def circle2(x, y, radius=1.2):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax2.add_artist(circle)

def text2(x, y, text, bgcolor):
    ax2.text(x, y, text, backgroundcolor=bgcolor,
            ha='center', va='top', weight='bold', color='k')
    
def rightSide_ylabels():
    ax2 = ax.twinx()
    y1, y2 = ax.get_ylim()
    ax2.set_ylim(y1,y2)
    ax2.tick_params(axis='y', labelsize = 14)

# %%
"""
Produce diagram for D-01 Population (Global).
Data was adapted from Schweizer and O'Niell (2014)
"""
Sheetname = 'Population'
Fig_y_label = 'Population in billions'
Fig_title = 'Global Population Pathways'

# Get data into Pandas dataframe
Popdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Popdf[['Year','LM','MH']].plot(x='Year',ylim=[5,15],figsize=FIG_SIZE, fontsize = 14, legend = False)
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(Popdf['Year'], Popdf['LM'], Popdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(Popdf['Year'], Popdf['MH'], Popdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(Popdf['Year'], Popdf['LM-region'], Popdf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.7, 0.75, 'High Pathways', rotation=21,transform=ax.transAxes, fontsize=14)
ax.text(.7, 0.49, 'Medium Pathways', rotation=0,transform=ax.transAxes, fontsize=14)
ax.text(.7, 0.32, 'Low Pathways', rotation=-6.5,transform=ax.transAxes, fontsize=14)

# Add right side y-label and tick marks
#ax2 = ax.twinx()
#y1, y2 = ax.get_ylim()
#ax2.set_ylim(y1,y2)
#ax2.tick_params(axis='y', labelsize = 14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/GPopulation.png') # Save diagram as .png

# %%
"""
Produce diagram for D-02 Urbanization (Global).
Data was adapted from Schweizer and O'Niell (2014)
"""
Sheetname = 'Urbanization'
Fig_y_label = 'Percentage of population living in urban areas'
Fig_title = 'Global Urbanization Pathways'

# Get data into Pandas dataframe
Urbandf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Urbandf[['Year','LM','MH']].plot(x='Year', ylim=[40,100],figsize=FIG_SIZE,fontsize=14,legend=False)
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(Urbandf['Year'], Urbandf['LM'], Urbandf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(Urbandf['Year'], Urbandf['MH'], Urbandf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(Urbandf['Year'], Urbandf['LM-region'], Urbandf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.73, 0.69, 'High Pathways', rotation=12.5,transform=ax.transAxes, fontsize=14)
ax.text(.7, 0.55, 'Medium Pathways', rotation=12.5,transform=ax.transAxes, fontsize=14)
ax.text(.73, 0.38, 'Low Pathways', rotation=12.5,transform=ax.transAxes, fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/GUrbanization.png')  # Save diagram as .png

# %%
"""
Produce diagram for D-03 Tech Development in Negative Emission Technology (NET) (Global).
Data was adapted from Minx et al (2018)
"""
Sheetname = 'Tech-NET'
Fig_y_label = 'Gross negative emissions (GtCO2/year)'
Fig_title = 'Pathways for Technology Development in NET (Global)'

# Get data into Pandas dataframe
NTD_netdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = NTD_netdf[['Year','LM','MH']].plot(x='Year', ylim=[0,20], figsize=FIG_SIZE,fontsize=14, legend=False)
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(NTD_netdf['Year'], NTD_netdf['LM'], NTD_netdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(NTD_netdf['Year'], NTD_netdf['MH'], NTD_netdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(NTD_netdf['Year'], NTD_netdf['LM-region'], NTD_netdf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.92, 0.86, 'High Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.92, 0.6, 'Medium Pathways', rotation= 0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.92, 0.15, 'Low Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/GL_newtech_net.png') # Save diagram as .png

# %%
"""
Produce diagram for D-04 Carbon Intensity.
Data was adapted from Schweizer and O'Niell (2014) and IEA
"""
Sheetname = 'Carbon Intensity CA'
Fig_y_label = 'CO2/TPES in tonnes per Terajoules'
Fig_title = 'Canada Carbon Intensity Pathways'

# Get data into Pandas dataframe
Co2cadf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Co2cadf[['Year','LM','MH']].plot(x='Year', ylim=[0,100], figsize=FIG_SIZE,fontsize=14,legend=False)
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(Co2cadf['Year'], Co2cadf['LM'], Co2cadf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(Co2cadf['Year'], Co2cadf['MH'], Co2cadf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(Co2cadf['Year'], Co2cadf['LM-region'], Co2cadf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.92, 0.70, 'High Pathways', rotation=13,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.92, 0.39, 'Medium Pathways', rotation= 0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.92, 0.15, 'Low Pathways', rotation=-12.5,transform=ax.transAxes,horizontalalignment='right', fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CACo2intensity.png') # Save diagram as .png

# %%
"""
Produce diagram for D-05 Income.
Data was adapted from SSP Database curated by IIASA, see Riahi et al (2017)
"""
Sheetname = 'Income CA'
Fig_y_label = 'US dollars 2005 per year'
Fig_title = 'Canada Income per Capita'

# Get data into Pandas dataframe
Incomecatdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Incomecatdf[['Year','LM','MH','SSP3','SSP5','SSP1','SSP2','SSP4']].plot(x='Year', ylim=[20000,170000],figsize=FIG_SIZE, fontsize=14,legend=False, style=['-','-',':',':',':',':',':'])
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(Incomecatdf['Year'], Incomecatdf['LM'], Incomecatdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(Incomecatdf['Year'], Incomecatdf['MH'], Incomecatdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(Incomecatdf['Year'], Incomecatdf['LM-region'], Incomecatdf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.95, 0.69, 'High Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.95, 0.48, 'Medium Pathways', rotation= 0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.95, 0.23, 'Low Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.5, 0.46, 'SSP5 Pathways', rotation=29,transform=ax.transAxes,horizontalalignment='center', fontsize=14)
ax.text(.5, 0.2, 'SSP3 Pathways', rotation=12,transform=ax.transAxes,horizontalalignment='center', fontsize=14)
ax.text(.55, 0.37, 'SSP1,2,4 Pathways', rotation=16,transform=ax.transAxes,horizontalalignment='center', fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CAincome.png') # Save diagram as .png

# %%
"""
Produce diagram for D-06 Tech Development in Green Freight Transport.
Data was adapated and informed by Sovacool (2016)
"""
Sheetname = 'Tech-Freight'
Fig_y_label = 'Percentage of technology adoption'
Fig_title = 'Pathways for Technology Development in Green Freight Transport'

# Get data into Pandas dataframe
NTD_greenfreightdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = NTD_greenfreightdf[['Year','LM','MH','Rail']].plot(x='Year', ylim=[0,100],figsize=FIG_SIZE,fontsize=14,legend=False, style=['-','-',':'])
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(NTD_greenfreightdf['Year'], NTD_greenfreightdf['LM'], NTD_greenfreightdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(NTD_greenfreightdf['Year'], NTD_greenfreightdf['MH'], NTD_greenfreightdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(NTD_greenfreightdf['Year'], NTD_greenfreightdf['LM-region'], NTD_greenfreightdf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.93, 0.93, 'High Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.93, 0.6, 'Medium Pathways', rotation= 0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.93, 0.23, 'Low Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.45, 0.37, 'Technology diffusion rate for railways', rotation=28.2,transform=ax.transAxes,horizontalalignment='center', fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CA_newtech_greenfreight.png') # Save diagram as .png

# %%
"""
Produce diagram for D-07 Tech Development in Green Transit.
Data was adapated and informed by Sovacool (2016) and Cox and Alm (2008)
"""
Sheetname = 'Tech-Pass'
Fig_y_label = 'Percentage of technology adoption'
Fig_title = 'Pathways for Technology Development in Green Transit'

# Get data into Pandas dataframe
NTD_greenpassdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = NTD_greenpassdf[['Year','LM','MH','Referenc']].plot(x='Year', ylim=[0,100], figsize=FIG_SIZE, fontsize=14,legend=False,style=['-','-',':'])
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(NTD_greenpassdf['Year'], NTD_greenpassdf['LM'], NTD_greenpassdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(NTD_greenpassdf['Year'], NTD_greenpassdf['MH'], NTD_greenpassdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(NTD_greenpassdf['Year'], NTD_greenpassdf['LM-region'], NTD_greenpassdf['LM'],facecolor='lightblue', interpolate=True)
# Plot the text strings and labels
ax.text(.93, 0.96, 'High Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.93, 0.79, 'Medium Pathways', rotation= 33,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.93, 0.65, 'Low Pathways', rotation=33,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.47, 0.77, 'Technology diffusion (mean) rate for autos* and railways', rotation=33,transform=ax.transAxes,horizontalalignment='center', fontsize=14)
ax.text(.55, 0.02, '*Note: Diffusion rate is adjusted to exclude the\n period of the Great Depression and World War II', rotation=0,transform=ax.transAxes,horizontalalignment='left', fontsize=12)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CA_newtech_greenpass.png') # Save diagram as .png

# %%
"""
Produce diagram for D-08 Adoption of Electric Vehicles.
Data was informed by Pathways to Deep Decarbonization Report (Bataille et al, 2016)
"""
Sheetname = 'Adoption of EVs'
Fig_y_label = 'Percentage of market share of electric vehicles'
Fig_title = 'Pathways for Adoption of Electric Vehicles'

# Get data into Pandas dataframe
Adoptevdf = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Adoptevdf[['Year','LM','MH','Auto']].plot(x='Year', ylim=[0,100], figsize= FIG_SIZE, fontsize=14,legend=False, style=['-','-',':'])
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(Adoptevdf['Year'], Adoptevdf['LM'], Adoptevdf['MH'],facecolor='aquamarine', interpolate=True)
ax.fill_between(Adoptevdf['Year'], Adoptevdf['MH'], Adoptevdf['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(Adoptevdf['Year'], Adoptevdf['LM-region'], Adoptevdf['LM'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.65, 0.96, 'High Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.91, 0.91, 'Medium Pathways', rotation= 0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.93, 0.65, 'Low Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='right', fontsize=14)
ax.text(.57, 0.84, 'Technology diffusion rate for autos*', rotation=15,transform=ax.transAxes,horizontalalignment='center', fontsize=14)
ax.text(.55, 0.02, '*Note: Diffusion rate is adjusted to exclude the\n period of the Great Depression and World War II', rotation=0,transform=ax.transAxes,horizontalalignment='left', fontsize=12)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CAAdoptEV.png') # Save diagram as .png

# %%
"""
Produce diagram for D-09 Carbon Intensity (Global).
Data was adapted from Schweizer and O'Niell (2014)
"""
Sheetname = 'Carbon Intensity'
Fig_y_label ='CO2/TPES in tonnes per Terajoules'
Fig_title = 'Global Carbon Intensity Pathways'

# Get data into Pandas dataframe
co2df = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = co2df[['Year','M']].plot(x='Year', ylim=[20,70], figsize=FIG_SIZE, fontsize=14,legend=False)
plt.title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
ax.fill_between(co2df['Year'], co2df['M'], co2df['MH-region'],facecolor='khaki', interpolate=True)
ax.fill_between(co2df['Year'], co2df['LM-region'], co2df['M'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax.text(.85, 0.72, 'Higher Pathways', rotation=0,transform=ax.transAxes,horizontalalignment='center', fontsize=14)
ax.text(.85, 0.34, 'Lower Pathways', rotation=-20,transform=ax.transAxes,horizontalalignment='center', fontsize=14)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/GCo2intensity.png') # Save diagram as .png

# %%
"""
Produce diagram for D-10 Decarbonized Economy Pathways.
Data on GDP by industrial sector are retrieved from Statistic Canada 
"""
Sheetname = 'Decarbonized1'
Fig_y_label = 'Growth (%)'
Fig_title = "Decarbonized Economy Pathways"

# Get data into Pandas dataframe
Decarb1df = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
ax = Decarb1df.plot(x='Year', ylim=[-5,10],fontsize=14, figsize=FIG_SIZE, legend=True)
ax.set_xticks(ax.get_xticks()[::2])
ax.set_title(Fig_title, fontsize=20)
ax.set_ylabel(Fig_y_label,fontsize=14)
ax.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
circle(2015.5, 1.7)
text(2015.5, 0.25, "Coupled", "khaki")

circle(2004, 2)
text(2004, 0.55, "De-coupled", "lightblue")

# Plot the text strings and labels
ax.text(.98, 0.02, 'Note: GDP growth has been historically coupled with the oil and gas production', transform=ax.transAxes,horizontalalignment='right', fontsize=10)

# Add right side y-label and tick marks
rightSide_ylabels()

plt.savefig('./figures/CA_decarbonized-v1.png') # Save diagram as .png
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle("Conjoined Descriptor D-09*D-10",fontsize=20,x=0.5,y=0.94)

"""
Subplot 1 (D-09)
"""

Sheetname = 'Carbon Intensity'
Fig_y_label ='CO2/TPES in tonnes per Terajoules'
Fig_title = 'D-09 Global Carbon Intensity Pathways'

# Get data into Pandas dataframe
co2df = pd.read_excel(FILENAME, sheet_name=Sheetname)

# Ploting the high and low pathways
co2df[['Year','M']].plot(ax=ax1, x='Year', ylim=[20,70], figsize=(24,8), fontsize=14,legend=False)
ax1.set_ylabel(Fig_y_label,fontsize=14)
ax1.set_xlabel('Year',fontsize=14)
ax1.set_title(Fig_title,fontsize=16)

# Plot the shading for each region
ax1.fill_between(co2df['Year'], co2df['M'], co2df['MH-region'],facecolor='khaki', interpolate=True)
ax1.fill_between(co2df['Year'], co2df['LM-region'], co2df['M'],facecolor='lightblue', interpolate=True)

# Plot the text strings and labels
ax1.text(.85, 0.72, 'Higher Pathways', rotation=0,transform=ax1.transAxes,horizontalalignment='center', fontsize=14)
ax1.text(.85, 0.34, 'Lower Pathways', rotation=-20,transform=ax1.transAxes,horizontalalignment='center', fontsize=14)

"""
Subplot 2 (D-10)
"""
Sheetname = 'Decarbonized1'
Fig_y_label = 'Growth (%)'
Fig_title = "D-10 Decarbonized Economy Pathways"

# Get data into Pandas dataframe
Decarb1df = pd.read_excel(FILENAME, sheet_name=Sheetname)
#Decarb1df['Year'] = Decarb1df['Year'].astype(str)

# Ploting the high and low pathways
Decarb1df.plot(ax=ax2, x='Year', ylim=[-5,10],fontsize=14, figsize=(24,8), legend=True)
ax2.set_xticks(ax2.get_xticks()[::2])
ax2.set_title(Fig_title, fontsize=16)
ax2.set_ylabel(Fig_y_label,fontsize=14)
ax2.set_xlabel('Year',fontsize=14)

# Plot the shading for each region
circle2(2015.5, 1.7)
text2(2015.5, 0.25, "Coupled", "khaki")
circle2(2004, 2)
text2(2004, 0.55, "De-coupled", "lightblue")

# Plot the text strings and labels
ax2.text(.98, 0.02, 'Note: GDP growth has been historically coupled with the oil and gas production', transform=ax2.transAxes,horizontalalignment='right', fontsize=10)

plt.savefig('./figures/conjointdesc.png',bbox_inches="tight")

plt.show()
